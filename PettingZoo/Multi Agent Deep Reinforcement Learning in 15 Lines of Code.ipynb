# %% [markdown]
# ## Training Agents

# %% [markdown]
# 1. Load required libraries:

# %%
from stable_baselines3.ppo import CnnPolicy
from stable_baselines3 import PPO
from pettingzoo.butterfly import pistonball_v5
import supersuit as ss

# %% [markdown]
# 2. Initialize the PettingZoo environment:

# %%
env = pistonball_v5.parallel_env(n_pistons=20, time_penalty=-0.1, 
                                 continuous=True, random_drop=True, 
                                 random_rotate=True, ball_mass=0.75, 
                                 ball_friction=0.3, ball_elasticity=1.5, 
                                 max_cycles=125)

# %% [markdown]
# 3. We wrap our environment in SuperSuit to remove the 3 color channels, as we only need grey scale for this task

# %%
env = ss.color_reduction_v0(env, mode='B')

# %% [markdown]
# 4. We resize our input to 84x84 pixels

# %%
env = ss.resize_v0(env, x_size=84, y_size=84)

# %% [markdown]
# 5. We stack the previous frames together to give information related to the balls movement

# %%
env = ss.frame_stack_v1(env, 4)

# %% [markdown]
# 6. We convert the environments API which causes Stable Baselines to do parameter sharing of the policy network on a multiagent environment

# %%
env = ss.pettingzoo_env_to_vec_env_v1(env)

# %% [markdown]
# 7. This step enables parallel training

# %%
# 8 threads on 4 cpus
env = ss.concat_vec_envs_v1(env, 8, num_cpus=4, base_class='stable_baselines3')

# %% [markdown]
# 8. We can finally train our agent

# %%
model = PPO(CnnPolicy, env, verbose=3, gamma=0.95, n_steps=256,
            ent_coef=0.0905168, learning_rate=0.0006221, vf_coef=0.042202,
            max_grad_norm=0.9, gae_lambda=0.99, n_epochs=5, clip_range=0.3,
            batch_size=256)

model.learn(total_timesteps=2_000_000)

model.save('policy')
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# ------------------------------
# | time/              |       |
# |    fps             | 2877  |
# |    iterations      | 1     |
# |    time_elapsed    | 14    |
# |    total_timesteps | 40960 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1994        |
# |    iterations           | 2           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.011979329 |
# |    clip_fraction        | 0.0433      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0.051       |
# |    learning_rate        | 0.000622    |
# |    loss                 | 0.11        |
# |    n_updates            | 5           |
# |    policy_gradient_loss | 0.00314     |
# |    std                  | 1.12        |
# |    value_loss           | 9.69        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1793        |
# |    iterations           | 3           |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.014359267 |
# |    clip_fraction        | 0.0475      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -1.63       |
# |    explained_variance   | 0.0184      |
# |    learning_rate        | 0.000622    |
# |    loss                 | 0.0477      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | 0.00286     |
# |    std                  | 1.27        |
# |    value_loss           | 7.49        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1708        |
# |    iterations           | 4           |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.017560977 |
# |    clip_fraction        | 0.0486      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | 0.0342      |
# |    learning_rate        | 0.000622    |
# |    loss                 | 0.309       |
# |    n_updates            | 15          |
# |    policy_gradient_loss | 0.00366     |
# |    std                  | 1.46        |
# |    value_loss           | 17.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1660        |
# |    iterations           | 5           |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.015787747 |
# |    clip_fraction        | 0.0481      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | -0.0378     |
# |    learning_rate        | 0.000622    |
# |    loss                 | 0.114       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | 0.00244     |
# |    std                  | 1.64        |
# |    value_loss           | 8.23        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1634        |
# |    iterations           | 6           |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.013541169 |
# |    clip_fraction        | 0.0467      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -2          |
# |    explained_variance   | 0.00726     |
# |    learning_rate        | 0.000622    |
# |    loss                 | 0.274       |
# |    n_updates            | 25          |
# |    policy_gradient_loss | 0.00286     |
# |    std                  | 1.83        |
# |    value_loss           | 15.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1632        |
# |    iterations           | 7           |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.011406498 |
# |    clip_fraction        | 0.0423      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -2.09       |
# |    explained_variance   | -0.0122     |
# |    learning_rate        | 0.000622    |
# |    loss                 | 0.692       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.00372     |
# |    std                  | 1.99        |
# |    value_loss           | 23.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1614        |
# |    iterations           | 8           |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.013276475 |
# |    clip_fraction        | 0.0451      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -2.19       |
# |    explained_variance   | 0.0914      |
# |    learning_rate        | 0.000622    |
# |    loss                 | 0.573       |
# |    n_updates            | 35          |
# |    policy_gradient_loss | 0.00174     |
# |    std                  | 2.19        |
# |    value_loss           | 26.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1597        |
# |    iterations           | 9           |
# |    time_elapsed         | 230         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.013671634 |
# |    clip_fraction        | 0.0489      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -2.28       |
# |    explained_variance   | -0.0296     |
# |    learning_rate        | 0.000622    |
# |    loss                 | 0.971       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.000618    |
# |    std                  | 2.41        |
# |    value_loss           | 27.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1585        |
# |    iterations           | 10          |
# |    time_elapsed         | 258         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.012653773 |
# |    clip_fraction        | 0.0473      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -2.36       |
# |    explained_variance   | -0.101      |
# |    learning_rate        | 0.000622    |
# |    loss                 | 0.475       |
# |    n_updates            | 45          |
# |    policy_gradient_loss | 0.000386    |
# |    std                  | 2.61        |
# |    value_loss           | 16          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1576        |
# |    iterations           | 11          |
# |    time_elapsed         | 285         |
# |    total_timesteps      | 450560      |
# | train/                  |             |
# |    approx_kl            | 0.010256144 |
# |    clip_fraction        | 0.0396      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -2.43       |
# |    explained_variance   | -0.0306     |
# |    learning_rate        | 0.000622    |
# |    loss                 | 1.12        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.000374    |
# |    std                  | 2.8         |
# |    value_loss           | 30.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1570        |
# |    iterations           | 12          |
# |    time_elapsed         | 313         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.009718051 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -2.5        |
# |    explained_variance   | -0.0135     |
# |    learning_rate        | 0.000622    |
# |    loss                 | 1.45        |
# |    n_updates            | 55          |
# |    policy_gradient_loss | 0.00121     |
# |    std                  | 2.99        |
# |    value_loss           | 44.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1563        |
# |    iterations           | 13          |
# |    time_elapsed         | 340         |
# |    total_timesteps      | 532480      |
# | train/                  |             |
# |    approx_kl            | 0.011387719 |
# |    clip_fraction        | 0.0374      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -2.58       |
# |    explained_variance   | 0.028       |
# |    learning_rate        | 0.000622    |
# |    loss                 | 1.7         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | 0.00204     |
# |    std                  | 3.26        |
# |    value_loss           | 43.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1558        |
# |    iterations           | 14          |
# |    time_elapsed         | 367         |
# |    total_timesteps      | 573440      |
# | train/                  |             |
# |    approx_kl            | 0.008878488 |
# |    clip_fraction        | 0.0329      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -2.66       |
# |    explained_variance   | -0.00541    |
# |    learning_rate        | 0.000622    |
# |    loss                 | 1.89        |
# |    n_updates            | 65          |
# |    policy_gradient_loss | 0.00115     |
# |    std                  | 3.48        |
# |    value_loss           | 52.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1555        |
# |    iterations           | 15          |
# |    time_elapsed         | 395         |
# |    total_timesteps      | 614400      |
# | train/                  |             |
# |    approx_kl            | 0.011436654 |
# |    clip_fraction        | 0.0425      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | -0.0215     |
# |    learning_rate        | 0.000622    |
# |    loss                 | 2.16        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | 0.0023      |
# |    std                  | 3.81        |
# |    value_loss           | 50.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1551        |
# |    iterations           | 16          |
# |    time_elapsed         | 422         |
# |    total_timesteps      | 655360      |
# | train/                  |             |
# |    approx_kl            | 0.012094177 |
# |    clip_fraction        | 0.0443      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0.00742     |
# |    learning_rate        | 0.000622    |
# |    loss                 | 2.62        |
# |    n_updates            | 75          |
# |    policy_gradient_loss | 0.00058     |
# |    std                  | 4.18        |
# |    value_loss           | 72.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1548        |
# |    iterations           | 17          |
# |    time_elapsed         | 449         |
# |    total_timesteps      | 696320      |
# | train/                  |             |
# |    approx_kl            | 0.010795238 |
# |    clip_fraction        | 0.0461      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -2.91       |
# |    explained_variance   | -0.105      |
# |    learning_rate        | 0.000622    |
# |    loss                 | 1.98        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | 0.0025      |
# |    std                  | 4.51        |
# |    value_loss           | 50.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1546        |
# |    iterations           | 18          |
# |    time_elapsed         | 476         |
# |    total_timesteps      | 737280      |
# | train/                  |             |
# |    approx_kl            | 0.010753969 |
# |    clip_fraction        | 0.0423      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -2.99       |
# |    explained_variance   | -0.00516    |
# |    learning_rate        | 0.000622    |
# |    loss                 | 1.53        |
# |    n_updates            | 85          |
# |    policy_gradient_loss | 0.00153     |
# |    std                  | 4.89        |
# |    value_loss           | 49          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1544        |
# |    iterations           | 19          |
# |    time_elapsed         | 503         |
# |    total_timesteps      | 778240      |
# | train/                  |             |
# |    approx_kl            | 0.009447031 |
# |    clip_fraction        | 0.0359      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -3.06       |
# |    explained_variance   | -0.00366    |
# |    learning_rate        | 0.000622    |
# |    loss                 | 1.62        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.0014      |
# |    std                  | 5.3         |
# |    value_loss           | 46.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1542        |
# |    iterations           | 20          |
# |    time_elapsed         | 531         |
# |    total_timesteps      | 819200      |
# | train/                  |             |
# |    approx_kl            | 0.011151271 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -3.15       |
# |    explained_variance   | 0.0152      |
# |    learning_rate        | 0.000622    |
# |    loss                 | 2.23        |
# |    n_updates            | 95          |
# |    policy_gradient_loss | 0.00129     |
# |    std                  | 5.74        |
# |    value_loss           | 58.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1540        |
# |    iterations           | 21          |
# |    time_elapsed         | 558         |
# |    total_timesteps      | 860160      |
# | train/                  |             |
# |    approx_kl            | 0.010904403 |
# |    clip_fraction        | 0.037       |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -3.23       |
# |    explained_variance   | 0.00125     |
# |    learning_rate        | 0.000622    |
# |    loss                 | 4.47        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.00177     |
# |    std                  | 6.27        |
# |    value_loss           | 101         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1538        |
# |    iterations           | 22          |
# |    time_elapsed         | 585         |
# |    total_timesteps      | 901120      |
# | train/                  |             |
# |    approx_kl            | 0.010881124 |
# |    clip_fraction        | 0.0439      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -3.33       |
# |    explained_variance   | -0.0359     |
# |    learning_rate        | 0.000622    |
# |    loss                 | 2.55        |
# |    n_updates            | 105         |
# |    policy_gradient_loss | 0.00269     |
# |    std                  | 6.84        |
# |    value_loss           | 60.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1537        |
# |    iterations           | 23          |
# |    time_elapsed         | 612         |
# |    total_timesteps      | 942080      |
# | train/                  |             |
# |    approx_kl            | 0.009103665 |
# |    clip_fraction        | 0.0356      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -3.41       |
# |    explained_variance   | 0.0444      |
# |    learning_rate        | 0.000622    |
# |    loss                 | 2.85        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.00222     |
# |    std                  | 7.41        |
# |    value_loss           | 71.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1536        |
# |    iterations           | 24          |
# |    time_elapsed         | 639         |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.008047774 |
# |    clip_fraction        | 0.0342      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -3.48       |
# |    explained_variance   | 0.0174      |
# |    learning_rate        | 0.000622    |
# |    loss                 | 1.72        |
# |    n_updates            | 115         |
# |    policy_gradient_loss | 0.00142     |
# |    std                  | 7.94        |
# |    value_loss           | 54.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1534         |
# |    iterations           | 25           |
# |    time_elapsed         | 667          |
# |    total_timesteps      | 1024000      |
# | train/                  |              |
# |    approx_kl            | 0.0114335865 |
# |    clip_fraction        | 0.0458       |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -3.56        |
# |    explained_variance   | 0.000286     |
# |    learning_rate        | 0.000622     |
# |    loss                 | 1.76         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | 0.00238      |
# |    std                  | 8.63         |
# |    value_loss           | 45.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1533        |
# |    iterations           | 26          |
# |    time_elapsed         | 694         |
# |    total_timesteps      | 1064960     |
# | train/                  |             |
# |    approx_kl            | 0.010542321 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -3.64       |
# |    explained_variance   | 0.0302      |
# |    learning_rate        | 0.000622    |
# |    loss                 | 1.37        |
# |    n_updates            | 125         |
# |    policy_gradient_loss | 0.0011      |
# |    std                  | 9.35        |
# |    value_loss           | 51          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1532        |
# |    iterations           | 27          |
# |    time_elapsed         | 721         |
# |    total_timesteps      | 1105920     |
# | train/                  |             |
# |    approx_kl            | 0.008090011 |
# |    clip_fraction        | 0.0333      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -3.71       |
# |    explained_variance   | -0.00773    |
# |    learning_rate        | 0.000622    |
# |    loss                 | 1.77        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.00136     |
# |    std                  | 10.1        |
# |    value_loss           | 53.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1531        |
# |    iterations           | 28          |
# |    time_elapsed         | 749         |
# |    total_timesteps      | 1146880     |
# | train/                  |             |
# |    approx_kl            | 0.008757403 |
# |    clip_fraction        | 0.0342      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -3.79       |
# |    explained_variance   | 0.0409      |
# |    learning_rate        | 0.000622    |
# |    loss                 | 2.02        |
# |    n_updates            | 135         |
# |    policy_gradient_loss | 0.00164     |
# |    std                  | 10.8        |
# |    value_loss           | 63.1        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1530       |
# |    iterations           | 29         |
# |    time_elapsed         | 776        |
# |    total_timesteps      | 1187840    |
# | train/                  |            |
# |    approx_kl            | 0.00802633 |
# |    clip_fraction        | 0.0357     |
# |    clip_range           | 0.3        |
# |    entropy_loss         | -3.86      |
# |    explained_variance   | 0.00798    |
# |    learning_rate        | 0.000622   |
# |    loss                 | 1.85       |
# |    n_updates            | 140        |
# |    policy_gradient_loss | 0.00186    |
# |    std                  | 11.6       |
# |    value_loss           | 54.9       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1528        |
# |    iterations           | 30          |
# |    time_elapsed         | 803         |
# |    total_timesteps      | 1228800     |
# | train/                  |             |
# |    approx_kl            | 0.008595651 |
# |    clip_fraction        | 0.0362      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -3.94       |
# |    explained_variance   | 0.0185      |
# |    learning_rate        | 0.000622    |
# |    loss                 | 2.05        |
# |    n_updates            | 145         |
# |    policy_gradient_loss | 0.00238     |
# |    std                  | 12.5        |
# |    value_loss           | 58.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1527        |
# |    iterations           | 31          |
# |    time_elapsed         | 831         |
# |    total_timesteps      | 1269760     |
# | train/                  |             |
# |    approx_kl            | 0.008353134 |
# |    clip_fraction        | 0.0336      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -4.02       |
# |    explained_variance   | 0.0205      |
# |    learning_rate        | 0.000622    |
# |    loss                 | 2.85        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.00243     |
# |    std                  | 13.6        |
# |    value_loss           | 66.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1527        |
# |    iterations           | 32          |
# |    time_elapsed         | 857         |
# |    total_timesteps      | 1310720     |
# | train/                  |             |
# |    approx_kl            | 0.009184985 |
# |    clip_fraction        | 0.0397      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | 0.054       |
# |    learning_rate        | 0.000622    |
# |    loss                 | 1.92        |
# |    n_updates            | 155         |
# |    policy_gradient_loss | 0.00201     |
# |    std                  | 14.7        |
# |    value_loss           | 54.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1527        |
# |    iterations           | 33          |
# |    time_elapsed         | 885         |
# |    total_timesteps      | 1351680     |
# | train/                  |             |
# |    approx_kl            | 0.009602084 |
# |    clip_fraction        | 0.0366      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.00721     |
# |    learning_rate        | 0.000622    |
# |    loss                 | 2.11        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.00173     |
# |    std                  | 15.9        |
# |    value_loss           | 62          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1526         |
# |    iterations           | 34           |
# |    time_elapsed         | 912          |
# |    total_timesteps      | 1392640      |
# | train/                  |              |
# |    approx_kl            | 0.0072430028 |
# |    clip_fraction        | 0.0311       |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -4.24        |
# |    explained_variance   | 0.0107       |
# |    learning_rate        | 0.000622     |
# |    loss                 | 2.4          |
# |    n_updates            | 165          |
# |    policy_gradient_loss | 0.00218      |
# |    std                  | 16.9         |
# |    value_loss           | 60.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1525        |
# |    iterations           | 35          |
# |    time_elapsed         | 939         |
# |    total_timesteps      | 1433600     |
# | train/                  |             |
# |    approx_kl            | 0.010573791 |
# |    clip_fraction        | 0.0378      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -4.32       |
# |    explained_variance   | 0.0243      |
# |    learning_rate        | 0.000622    |
# |    loss                 | 2.6         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.00151     |
# |    std                  | 18.5        |
# |    value_loss           | 69.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1524        |
# |    iterations           | 36          |
# |    time_elapsed         | 967         |
# |    total_timesteps      | 1474560     |
# | train/                  |             |
# |    approx_kl            | 0.007748385 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -4.39       |
# |    explained_variance   | 0.00789     |
# |    learning_rate        | 0.000622    |
# |    loss                 | 2.92        |
# |    n_updates            | 175         |
# |    policy_gradient_loss | 0.00193     |
# |    std                  | 19.9        |
# |    value_loss           | 78.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1524        |
# |    iterations           | 37          |
# |    time_elapsed         | 994         |
# |    total_timesteps      | 1515520     |
# | train/                  |             |
# |    approx_kl            | 0.008257687 |
# |    clip_fraction        | 0.0323      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -4.47       |
# |    explained_variance   | 0.00995     |
# |    learning_rate        | 0.000622    |
# |    loss                 | 2.38        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.00191     |
# |    std                  | 21.5        |
# |    value_loss           | 66.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1523        |
# |    iterations           | 38          |
# |    time_elapsed         | 1021        |
# |    total_timesteps      | 1556480     |
# | train/                  |             |
# |    approx_kl            | 0.008381849 |
# |    clip_fraction        | 0.0329      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -4.56       |
# |    explained_variance   | 0.0168      |
# |    learning_rate        | 0.000622    |
# |    loss                 | 2.28        |
# |    n_updates            | 185         |
# |    policy_gradient_loss | 0.0016      |
# |    std                  | 23.4        |
# |    value_loss           | 55.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1522         |
# |    iterations           | 39           |
# |    time_elapsed         | 1049         |
# |    total_timesteps      | 1597440      |
# | train/                  |              |
# |    approx_kl            | 0.0074452595 |
# |    clip_fraction        | 0.0292       |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -4.64        |
# |    explained_variance   | 0.0275       |
# |    learning_rate        | 0.000622     |
# |    loss                 | 1.79         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | 0.00159      |
# |    std                  | 25.3         |
# |    value_loss           | 50.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1521        |
# |    iterations           | 40          |
# |    time_elapsed         | 1076        |
# |    total_timesteps      | 1638400     |
# | train/                  |             |
# |    approx_kl            | 0.008060398 |
# |    clip_fraction        | 0.0323      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -4.72       |
# |    explained_variance   | 0.0447      |
# |    learning_rate        | 0.000622    |
# |    loss                 | 2.34        |
# |    n_updates            | 195         |
# |    policy_gradient_loss | 0.00141     |
# |    std                  | 27.5        |
# |    value_loss           | 66.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1521        |
# |    iterations           | 41          |
# |    time_elapsed         | 1104        |
# |    total_timesteps      | 1679360     |
# | train/                  |             |
# |    approx_kl            | 0.007358077 |
# |    clip_fraction        | 0.0288      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -4.8        |
# |    explained_variance   | -0.0278     |
# |    learning_rate        | 0.000622    |
# |    loss                 | 1.74        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.0015      |
# |    std                  | 29.5        |
# |    value_loss           | 62.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1520        |
# |    iterations           | 42          |
# |    time_elapsed         | 1131        |
# |    total_timesteps      | 1720320     |
# | train/                  |             |
# |    approx_kl            | 0.008195897 |
# |    clip_fraction        | 0.0319      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -4.87       |
# |    explained_variance   | -0.0216     |
# |    learning_rate        | 0.000622    |
# |    loss                 | 2.24        |
# |    n_updates            | 205         |
# |    policy_gradient_loss | 0.0021      |
# |    std                  | 32          |
# |    value_loss           | 64.7        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1520         |
# |    iterations           | 43           |
# |    time_elapsed         | 1158         |
# |    total_timesteps      | 1761280      |
# | train/                  |              |
# |    approx_kl            | 0.0080920495 |
# |    clip_fraction        | 0.0288       |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -4.95        |
# |    explained_variance   | 0.0127       |
# |    learning_rate        | 0.000622     |
# |    loss                 | 2.55         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | 0.00165      |
# |    std                  | 34.7         |
# |    value_loss           | 89.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1519        |
# |    iterations           | 44          |
# |    time_elapsed         | 1185        |
# |    total_timesteps      | 1802240     |
# | train/                  |             |
# |    approx_kl            | 0.008509882 |
# |    clip_fraction        | 0.0314      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -5.04       |
# |    explained_variance   | 0.012       |
# |    learning_rate        | 0.000622    |
# |    loss                 | 2.44        |
# |    n_updates            | 215         |
# |    policy_gradient_loss | 0.00169     |
# |    std                  | 37.9        |
# |    value_loss           | 70.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1519        |
# |    iterations           | 45          |
# |    time_elapsed         | 1212        |
# |    total_timesteps      | 1843200     |
# | train/                  |             |
# |    approx_kl            | 0.007270542 |
# |    clip_fraction        | 0.0298      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -5.12       |
# |    explained_variance   | -0.00946    |
# |    learning_rate        | 0.000622    |
# |    loss                 | 2.02        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00163     |
# |    std                  | 41          |
# |    value_loss           | 64.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1519        |
# |    iterations           | 46          |
# |    time_elapsed         | 1240        |
# |    total_timesteps      | 1884160     |
# | train/                  |             |
# |    approx_kl            | 0.007386832 |
# |    clip_fraction        | 0.0267      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -5.19       |
# |    explained_variance   | 0.0011      |
# |    learning_rate        | 0.000622    |
# |    loss                 | 3.06        |
# |    n_updates            | 225         |
# |    policy_gradient_loss | 0.00224     |
# |    std                  | 44.3        |
# |    value_loss           | 76.7        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1518         |
# |    iterations           | 47           |
# |    time_elapsed         | 1267         |
# |    total_timesteps      | 1925120      |
# | train/                  |              |
# |    approx_kl            | 0.0070904745 |
# |    clip_fraction        | 0.0259       |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -5.27        |
# |    explained_variance   | -0.00995     |
# |    learning_rate        | 0.000622     |
# |    loss                 | 2.92         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | 0.00195      |
# |    std                  | 47.5         |
# |    value_loss           | 96.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1518        |
# |    iterations           | 48          |
# |    time_elapsed         | 1294        |
# |    total_timesteps      | 1966080     |
# | train/                  |             |
# |    approx_kl            | 0.009256099 |
# |    clip_fraction        | 0.0362      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -5.36       |
# |    explained_variance   | -0.00379    |
# |    learning_rate        | 0.000622    |
# |    loss                 | 2.66        |
# |    n_updates            | 235         |
# |    policy_gradient_loss | 0.00135     |
# |    std                  | 52.1        |
# |    value_loss           | 83.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1517        |
# |    iterations           | 49          |
# |    time_elapsed         | 1322        |
# |    total_timesteps      | 2007040     |
# | train/                  |             |
# |    approx_kl            | 0.008087512 |
# |    clip_fraction        | 0.0321      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -5.44       |
# |    explained_variance   | 0.0307      |
# |    learning_rate        | 0.000622    |
# |    loss                 | 2.98        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.0018      |
# |    std                  | 56.5        |
# |    value_loss           | 88.2        |
# -----------------------------------------

# %% [markdown]
# ## Watching Agents Play

# %% [markdown]
# Now that the model is trained and saved, we can load the policy and watch it play!

# %% [markdown]
# We reinstantiate the environment

# %%
env = pistonball_v5.env()
env = ss.color_reduction_v0(env, mode='B')
env = ss.resize_v0(env, x_size=84, y_size=84)
env = ss.frame_stack_v1(env, 4)

# %% [markdown]
# Load the policy

# %%
model = PPO.load('policy')

# %% [markdown]
# And finally we can use the policy and render this

# %%
env.reset()
for agent in env.agent_iter():
    obs, reward, done, info = env.last()
    act = model.predict(obs, deterministic=True)[0] if not done else None
    env.step(act)
    env.render()

# %% [markdown]
# Finally, we close the environment.

# %%
env.close()
